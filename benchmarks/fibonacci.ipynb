# %%
from fibonacci import (
    fib_naive,
    fib_linear,
    fib_matmul_naive,
    fib_matmul_fastexp,
    fib_matmul_3var,
    fib_matmul_2var,
    fib_fast_doubling,
    fib_gmp,
)

from utils import plot_fixed_n_comparison

# %%
fib_all = [
    fib_naive,
    fib_matmul_naive,
    fib_linear,
    fib_matmul_fastexp,
    fib_matmul_3var,
    fib_matmul_2var,
    fib_fast_doubling,
    fib_gmp,
]

fib_treshold1 = fib_all[1:]  # Exclude fib_naive
fib_treshold2 = fib_all[2:]  # Exclude fib_naive and fib_matmul_naive
fib_treshold3 = fib_all[3:]  # Exclude fib_naive, fib_matmul_naive and fib_linear

# %%
plot_fixed_n_comparison(fib_all, n=38)
plot_fixed_n_comparison(fib_treshold1, n=300_000)
plot_fixed_n_comparison(fib_treshold2, n=1_000_000)
plot_fixed_n_comparison(fib_treshold3, n=30_000_000)
